# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import os
import random
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.style.use("ggplot")
# %matplotlib inline
from tqdm import tqdm
from tqdm import tqdm_notebook, tnrange
from itertools import chain
from skimage.io import imread, imshow, concatenate_images
from skimage.transform import resize
from skimage.morphology import label
from sklearn.model_selection import train_test_split

import tensorflow as tf
#import tensorflow.compat.v1 as tf
#tf.disable_v2_behavior()


gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
  try:
    # Currently, memory growth needs to be the same across GPUs
    for gpu in gpus:
      tf.config.experimental.set_memory_growth(gpu, True)
    logical_gpus = tf.config.experimental.list_logical_devices('GPU')
    print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
  except RuntimeError as e:
    # Memory growth must be set before GPUs have been initialized
    print(e)



from keras.models import Model, load_model
from keras.layers import Input, BatchNormalization, Activation, Dense, Dropout
from keras.layers.core import Lambda, RepeatVector, Reshape
from keras.layers.convolutional import Conv2D, Conv2DTranspose
from keras.layers.pooling import MaxPooling2D, GlobalMaxPool2D
from keras.layers.merge import concatenate, add
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from keras.optimizers import Adam
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# 1 Physical GPUs, 1 Logical GPUs
# Using TensorFlow backend.

# %%
# Set some parameters
im_width = 256
im_height = 256

train_ti_ids = next(os.walk("C:\MonuSeg_Short/Training/TissueImages/"))[2] # list of names all images in the given path
#print("No. of images = ", len(train_ti_ids))

train_gt_ids = []

for i in range( len(train_ti_ids) ):
    my_str = train_ti_ids[i]
    train_gt_ids.append(my_str)

    
test_ti_ids = next(os.walk("C:\MonuSeg_Short/Test/TissueImages/"))[2] # list of names all images in the given path
#print("No. of images = ", len(train_ti_ids))

test_gt_ids = []

for i in range( len(test_ti_ids) ):
    my_str = test_ti_ids[i]
    test_gt_ids.append(my_str)


def con_img_array(ids, base_path):
    X = np.zeros((len(ids), im_height, im_width, 1), dtype=np.float32)
    for i in (range(len(ids))):
        #print(ids[i])
        img = load_img( base_path + ids[i] , color_mode = "grayscale")
        x_img = img_to_array(img)
        x_img = resize(x_img, (im_height, im_width, 1), mode = 'constant', preserve_range = True)
        X[i] = x_img/255.0
    #print("=========================================")
    return X

def con_img_array_rgb(ids, base_path):
    X = np.zeros((len(ids), im_height, im_width, 3), dtype=np.float32)
    for i in (range(len(ids))):
        #print(ids[i])
        img = load_img( base_path + ids[i] , color_mode = "rgb")
        x_img = img_to_array(img)
        x_img = resize(x_img, (im_height, im_width, 3), mode = 'constant', preserve_range = True)
        X[i] = x_img/255.0
    #print("=========================================")
    return X


X_train = con_img_array_rgb(train_ti_ids, "C:\MonuSeg_Short/Training/TissueImages/")
y_train = con_img_array(train_gt_ids, "C:\MonuSeg_Short/Training/GroundTruth/")
X_test = con_img_array_rgb(test_ti_ids, "C:\MonuSeg_Short/Test/TissueImages/")
y_test = con_img_array(test_gt_ids, "C:\MonuSeg_Short/Test/GroundTruth/")

print(X_train.shape)
print(y_train.shape)

print(X_test.shape)
print(y_test.shape)

# %%
from numpy import save
save('X_train_short.npy', X_train)
save('y_train_short.npy', y_train)
save('X_test_short.npy', X_test)
save('y_test_short.npy', y_test)

# %%
from numpy import load
# load array
X_train = load('X_train_short.npy')
y_train = load('y_train_short.npy')
X_test = load('X_test_short.npy')
y_test = load('y_test_short.npy')

print(X_train.shape)
print(y_train.shape)

print(X_test.shape)
print(y_test.shape)
# Out:
# (1470, 256, 256, 3)
# (1470, 256, 256, 1)
# (686, 256, 256, 3)
# (686, 256, 256, 1)

# %%
from tensorflow.python.keras.models import Model
from tensorflow.python.keras import layers
from tensorflow.python.keras.layers import Input
from tensorflow.python.keras.layers import Lambda
from tensorflow.python.keras.layers import Activation
from tensorflow.python.keras.layers import Concatenate
from tensorflow.python.keras.layers import Add
from tensorflow.python.keras.layers import Dropout
from tensorflow.python.keras.layers import BatchNormalization
from tensorflow.python.keras.layers import Conv2D
from tensorflow.python.keras.layers import DepthwiseConv2D
from tensorflow.python.keras.layers import ZeroPadding2D
from tensorflow.python.keras.layers import GlobalAveragePooling2D
from tensorflow.python.keras.utils.layer_utils import get_source_inputs
from tensorflow.python.keras.utils.data_utils import get_file
from tensorflow.python.keras import backend as K
from tensorflow.python.keras.applications.imagenet_utils import preprocess_input

WEIGHTS_PATH_X = "https://github.com/bonlime/keras-deeplab-v3-plus/releases/download/1.1/deeplabv3_xception_tf_dim_ordering_tf_kernels.h5"
WEIGHTS_PATH_MOBILE = "https://github.com/bonlime/keras-deeplab-v3-plus/releases/download/1.1/deeplabv3_mobilenetv2_tf_dim_ordering_tf_kernels.h5"
WEIGHTS_PATH_X_CS = "https://github.com/bonlime/keras-deeplab-v3-plus/releases/download/1.2/deeplabv3_xception_tf_dim_ordering_tf_kernels_cityscapes.h5"
WEIGHTS_PATH_MOBILE_CS = "https://github.com/bonlime/keras-deeplab-v3-plus/releases/download/1.2/deeplabv3_mobilenetv2_tf_dim_ordering_tf_kernels_cityscapes.h5"


def SepConv_BN(x, filters, prefix, stride=1, kernel_size=3, rate=1, depth_activation=False, epsilon=1e-3):
    """ SepConv with BN between depthwise & pointwise. Optionally add activation after BN
        Implements right "same" padding for even kernel sizes
        Args:
            x: input tensor
            filters: num of filters in pointwise convolution
            prefix: prefix before name
            stride: stride at depthwise conv
            kernel_size: kernel size for depthwise convolution
            rate: atrous rate for depthwise convolution
            depth_activation: flag to use activation between depthwise & poinwise convs
            epsilon: epsilon to use in BN layer
    """

    if stride == 1:
        depth_padding = 'same'
    else:
        kernel_size_effective = kernel_size + (kernel_size - 1) * (rate - 1)
        pad_total = kernel_size_effective - 1
        pad_beg = pad_total // 2
        pad_end = pad_total - pad_beg
        x = ZeroPadding2D((pad_beg, pad_end))(x)
        depth_padding = 'valid'

    if not depth_activation:
        x = Activation(tf.nn.relu)(x)
    x = DepthwiseConv2D((kernel_size, kernel_size), strides=(stride, stride), dilation_rate=(rate, rate),
                        padding=depth_padding, use_bias=False, name=prefix + '_depthwise')(x)
    x = BatchNormalization(name=prefix + '_depthwise_BN', epsilon=epsilon)(x)
    if depth_activation:
        x = Activation(tf.nn.relu)(x)
    x = Conv2D(filters, (1, 1), padding='same',
               use_bias=False, name=prefix + '_pointwise')(x)
    x = BatchNormalization(name=prefix + '_pointwise_BN', epsilon=epsilon)(x)
    if depth_activation:
        x = Activation(tf.nn.relu)(x)

    return x


def _conv2d_same(x, filters, prefix, stride=1, kernel_size=3, rate=1):
    """Implements right 'same' padding for even kernel sizes
        Without this there is a 1 pixel drift when stride = 2
        Args:
            x: input tensor
            filters: num of filters in pointwise convolution
            prefix: prefix before name
            stride: stride at depthwise conv
            kernel_size: kernel size for depthwise convolution
            rate: atrous rate for depthwise convolution
    """
    if stride == 1:
        return Conv2D(filters,
                      (kernel_size, kernel_size),
                      strides=(stride, stride),
                      padding='same', use_bias=False,
                      dilation_rate=(rate, rate),
                      name=prefix)(x)
    else:
        kernel_size_effective = kernel_size + (kernel_size - 1) * (rate - 1)
        pad_total = kernel_size_effective - 1
        pad_beg = pad_total // 2
        pad_end = pad_total - pad_beg
        x = ZeroPadding2D((pad_beg, pad_end))(x)
        return Conv2D(filters,
                      (kernel_size, kernel_size),
                      strides=(stride, stride),
                      padding='valid', use_bias=False,
                      dilation_rate=(rate, rate),
                      name=prefix)(x)


def _xception_block(inputs, depth_list, prefix, skip_connection_type, stride,
                    rate=1, depth_activation=False, return_skip=False):
    """ Basic building block of modified Xception network
        Args:
            inputs: input tensor
            depth_list: number of filters in each SepConv layer. len(depth_list) == 3
            prefix: prefix before name
            skip_connection_type: one of {'conv','sum','none'}
            stride: stride at last depthwise conv
            rate: atrous rate for depthwise convolution
            depth_activation: flag to use activation between depthwise & pointwise convs
            return_skip: flag to return additional tensor after 2 SepConvs for decoder
            """
    residual = inputs
    for i in range(3):
        residual = SepConv_BN(residual,
                              depth_list[i],
                              prefix + '_separable_conv{}'.format(i + 1),
                              stride=stride if i == 2 else 1,
                              rate=rate,
                              depth_activation=depth_activation)
        if i == 1:
            skip = residual
    if skip_connection_type == 'conv':
        shortcut = _conv2d_same(inputs, depth_list[-1], prefix + '_shortcut',
                                kernel_size=1,
                                stride=stride)
        shortcut = BatchNormalization(name=prefix + '_shortcut_BN')(shortcut)
        outputs = layers.add([residual, shortcut])
    elif skip_connection_type == 'sum':
        outputs = layers.add([residual, inputs])
    elif skip_connection_type == 'none':
        outputs = residual
    if return_skip:
        return outputs, skip
    else:
        return outputs


def _make_divisible(v, divisor, min_value=None):
    if min_value is None:
        min_value = divisor
    new_v = max(min_value, int(v + divisor / 2) // divisor * divisor)
    # Make sure that round down does not go down by more than 10%.
    if new_v < 0.9 * v:
        new_v += divisor
    return new_v


def _inverted_res_block(inputs, expansion, stride, alpha, filters, block_id, skip_connection, rate=1):
    in_channels = inputs.shape[-1].value  # inputs._keras_shape[-1]
    pointwise_conv_filters = int(filters * alpha)
    pointwise_filters = _make_divisible(pointwise_conv_filters, 8)
    x = inputs
    prefix = 'expanded_conv_{}_'.format(block_id)
    if block_id:
        # Expand

        x = Conv2D(expansion * in_channels, kernel_size=1, padding='same',
                   use_bias=False, activation=None,
                   name=prefix + 'expand')(x)
        x = BatchNormalization(epsilon=1e-3, momentum=0.999,
                               name=prefix + 'expand_BN')(x)
        x = Activation(tf.nn.relu6, name=prefix + 'expand_relu')(x)
    else:
        prefix = 'expanded_conv_'
    # Depthwise
    x = DepthwiseConv2D(kernel_size=3, strides=stride, activation=None,
                        use_bias=False, padding='same', dilation_rate=(rate, rate),
                        name=prefix + 'depthwise')(x)
    x = BatchNormalization(epsilon=1e-3, momentum=0.999,
                           name=prefix + 'depthwise_BN')(x)

    x = Activation(tf.nn.relu6, name=prefix + 'depthwise_relu')(x)

    # Project
    x = Conv2D(pointwise_filters,
               kernel_size=1, padding='same', use_bias=False, activation=None,
               name=prefix + 'project')(x)
    x = BatchNormalization(epsilon=1e-3, momentum=0.999,
                           name=prefix + 'project_BN')(x)

    if skip_connection:
        return Add(name=prefix + 'add')([inputs, x])

    # if in_channels == pointwise_filters and stride == 1:
    #    return Add(name='res_connect_' + str(block_id))([inputs, x])

    return x


def Deeplabv3(weights='pascal_voc', input_tensor=None, input_shape=(512, 512, 3), classes=21, backbone='mobilenetv2',
              OS=16, alpha=1., activation=None):
    """ Instantiates the Deeplabv3+ architecture
    Optionally loads weights pre-trained
    on PASCAL VOC or Cityscapes. This model is available for TensorFlow only.
    # Arguments
        weights: one of 'pascal_voc' (pre-trained on pascal voc),
            'cityscapes' (pre-trained on cityscape) or None (random initialization)
        input_tensor: optional Keras tensor (i.e. output of `layers.Input()`)
            to use as image input for the model.
        input_shape: shape of input image. format HxWxC
            PASCAL VOC model was trained on (512,512,3) images. None is allowed as shape/width
        classes: number of desired classes. PASCAL VOC has 21 classes, Cityscapes has 19 classes.
            If number of classes not aligned with the weights used, last layer is initialized randomly
        backbone: backbone to use. one of {'xception','mobilenetv2'}
        activation: optional activation to add to the top of the network.
            One of 'softmax', 'sigmoid' or None
        OS: determines input_shape/feature_extractor_output ratio. One of {8,16}.
            Used only for xception backbone.
        alpha: controls the width of the MobileNetV2 network. This is known as the
            width multiplier in the MobileNetV2 paper.
                - If `alpha` < 1.0, proportionally decreases the number
                    of filters in each layer.
                - If `alpha` > 1.0, proportionally increases the number
                    of filters in each layer.
                - If `alpha` = 1, default number of filters from the paper
                    are used at each layer.
            Used only for mobilenetv2 backbone. Pretrained is only available for alpha=1.
    # Returns
        A Keras model instance.
    # Raises
        RuntimeError: If attempting to run this model with a
            backend that does not support separable convolutions.
        ValueError: in case of invalid argument for `weights` or `backbone`
    """

    if not (weights in {'pascal_voc', 'cityscapes', None}):
        raise ValueError('The `weights` argument should be either '
                         '`None` (random initialization), `pascal_voc`, or `cityscapes` '
                         '(pre-trained on PASCAL VOC)')

    if not (backbone in {'xception', 'mobilenetv2'}):
        raise ValueError('The `backbone` argument should be either '
                         '`xception`  or `mobilenetv2` ')

    if input_tensor is None:
        img_input = Input(shape=input_shape)
    else:
        img_input = input_tensor

    if backbone == 'xception':
        if OS == 8:
            entry_block3_stride = 1
            middle_block_rate = 2  # ! Not mentioned in paper, but required
            exit_block_rates = (2, 4)
            atrous_rates = (12, 24, 36)
        else:
            entry_block3_stride = 2
            middle_block_rate = 1
            exit_block_rates = (1, 2)
            atrous_rates = (6, 12, 18)

        x = Conv2D(32, (3, 3), strides=(2, 2),
                   name='entry_flow_conv1_1', use_bias=False, padding='same')(img_input)
        x = BatchNormalization(name='entry_flow_conv1_1_BN')(x)
        x = Activation(tf.nn.relu)(x)

        x = _conv2d_same(x, 64, 'entry_flow_conv1_2', kernel_size=3, stride=1)
        x = BatchNormalization(name='entry_flow_conv1_2_BN')(x)
        x = Activation(tf.nn.relu)(x)

        x = _xception_block(x, [128, 128, 128], 'entry_flow_block1',
                            skip_connection_type='conv', stride=2,
                            depth_activation=False)
        x, skip1 = _xception_block(x, [256, 256, 256], 'entry_flow_block2',
                                   skip_connection_type='conv', stride=2,
                                   depth_activation=False, return_skip=True)

        x = _xception_block(x, [728, 728, 728], 'entry_flow_block3',
                            skip_connection_type='conv', stride=entry_block3_stride,
                            depth_activation=False)
        for i in range(16):
            x = _xception_block(x, [728, 728, 728], 'middle_flow_unit_{}'.format(i + 1),
                                skip_connection_type='sum', stride=1, rate=middle_block_rate,
                                depth_activation=False)

        x = _xception_block(x, [728, 1024, 1024], 'exit_flow_block1',
                            skip_connection_type='conv', stride=1, rate=exit_block_rates[0],
                            depth_activation=False)
        x = _xception_block(x, [1536, 1536, 2048], 'exit_flow_block2',
                            skip_connection_type='none', stride=1, rate=exit_block_rates[1],
                            depth_activation=True)

    else:
        OS = 8
        first_block_filters = _make_divisible(32 * alpha, 8)
        x = Conv2D(first_block_filters,
                   kernel_size=3,
                   strides=(2, 2), padding='same',
                   use_bias=False, name='Conv')(img_input)
        x = BatchNormalization(
            epsilon=1e-3, momentum=0.999, name='Conv_BN')(x)
        x = Activation(tf.nn.relu6, name='Conv_Relu6')(x)

        x = _inverted_res_block(x, filters=16, alpha=alpha, stride=1,
                                expansion=1, block_id=0, skip_connection=False)

        x = _inverted_res_block(x, filters=24, alpha=alpha, stride=2,
                                expansion=6, block_id=1, skip_connection=False)
        x = _inverted_res_block(x, filters=24, alpha=alpha, stride=1,
                                expansion=6, block_id=2, skip_connection=True)

        x = _inverted_res_block(x, filters=32, alpha=alpha, stride=2,
                                expansion=6, block_id=3, skip_connection=False)
        x = _inverted_res_block(x, filters=32, alpha=alpha, stride=1,
                                expansion=6, block_id=4, skip_connection=True)
        x = _inverted_res_block(x, filters=32, alpha=alpha, stride=1,
                                expansion=6, block_id=5, skip_connection=True)

        # stride in block 6 changed from 2 -> 1, so we need to use rate = 2
        x = _inverted_res_block(x, filters=64, alpha=alpha, stride=1,  # 1!
                                expansion=6, block_id=6, skip_connection=False)
        x = _inverted_res_block(x, filters=64, alpha=alpha, stride=1, rate=2,
                                expansion=6, block_id=7, skip_connection=True)
        x = _inverted_res_block(x, filters=64, alpha=alpha, stride=1, rate=2,
                                expansion=6, block_id=8, skip_connection=True)
        x = _inverted_res_block(x, filters=64, alpha=alpha, stride=1, rate=2,
                                expansion=6, block_id=9, skip_connection=True)

        x = _inverted_res_block(x, filters=96, alpha=alpha, stride=1, rate=2,
                                expansion=6, block_id=10, skip_connection=False)
        x = _inverted_res_block(x, filters=96, alpha=alpha, stride=1, rate=2,
                                expansion=6, block_id=11, skip_connection=True)
        x = _inverted_res_block(x, filters=96, alpha=alpha, stride=1, rate=2,
                                expansion=6, block_id=12, skip_connection=True)

        x = _inverted_res_block(x, filters=160, alpha=alpha, stride=1, rate=2,  # 1!
                                expansion=6, block_id=13, skip_connection=False)
        x = _inverted_res_block(x, filters=160, alpha=alpha, stride=1, rate=4,
                                expansion=6, block_id=14, skip_connection=True)
        x = _inverted_res_block(x, filters=160, alpha=alpha, stride=1, rate=4,
                                expansion=6, block_id=15, skip_connection=True)

        x = _inverted_res_block(x, filters=320, alpha=alpha, stride=1, rate=4,
                                expansion=6, block_id=16, skip_connection=False)

    # end of feature extractor

    # branching for Atrous Spatial Pyramid Pooling

    # Image Feature branch
    shape_before = tf.shape(x)
    b4 = GlobalAveragePooling2D()(x)
    # from (b_size, channels)->(b_size, 1, 1, channels)
    b4 = Lambda(lambda x: K.expand_dims(x, 1))(b4)
    b4 = Lambda(lambda x: K.expand_dims(x, 1))(b4)
    b4 = Conv2D(256, (1, 1), padding='same',
                use_bias=False, name='image_pooling')(b4)
    b4 = BatchNormalization(name='image_pooling_BN', epsilon=1e-5)(b4)
    b4 = Activation(tf.nn.relu)(b4)
    # upsample. have to use compat because of the option align_corners
    size_before = tf.keras.backend.int_shape(x)
    b4 = Lambda(lambda x: tf.compat.v1.image.resize(x, size_before[1:3],
                                                    method='bilinear', align_corners=True))(b4)
    # simple 1x1
    b0 = Conv2D(256, (1, 1), padding='same', use_bias=False, name='aspp0')(x)
    b0 = BatchNormalization(name='aspp0_BN', epsilon=1e-5)(b0)
    b0 = Activation(tf.nn.relu, name='aspp0_activation')(b0)

    # there are only 2 branches in mobilenetV2. not sure why
    if backbone == 'xception':
        # rate = 6 (12)
        b1 = SepConv_BN(x, 256, 'aspp1',
                        rate=atrous_rates[0], depth_activation=True, epsilon=1e-5)
        # rate = 12 (24)
        b2 = SepConv_BN(x, 256, 'aspp2',
                        rate=atrous_rates[1], depth_activation=True, epsilon=1e-5)
        # rate = 18 (36)
        b3 = SepConv_BN(x, 256, 'aspp3',
                        rate=atrous_rates[2], depth_activation=True, epsilon=1e-5)

        # concatenate ASPP branches & project
        x = Concatenate()([b4, b0, b1, b2, b3])
    else:
        x = Concatenate()([b4, b0])

    x = Conv2D(256, (1, 1), padding='same',
               use_bias=False, name='concat_projection')(x)
    x = BatchNormalization(name='concat_projection_BN', epsilon=1e-5)(x)
    x = Activation(tf.nn.relu)(x)
    x = Dropout(0.1)(x)
    # DeepLab v.3+ decoder

    if backbone == 'xception':
        # Feature projection
        # x4 (x2) block
        size_before2 = tf.keras.backend.int_shape(x)
        x = Lambda(lambda xx: tf.compat.v1.image.resize(xx,
                                                        skip1.shape[1:3],
                                                        method='bilinear', align_corners=True))(x)

        dec_skip1 = Conv2D(48, (1, 1), padding='same',
                           use_bias=False, name='feature_projection0')(skip1)
        dec_skip1 = BatchNormalization(
            name='feature_projection0_BN', epsilon=1e-5)(dec_skip1)
        dec_skip1 = Activation(tf.nn.relu)(dec_skip1)
        x = Concatenate()([x, dec_skip1])
        x = SepConv_BN(x, 256, 'decoder_conv0',
                       depth_activation=True, epsilon=1e-5)
        x = SepConv_BN(x, 256, 'decoder_conv1',
                       depth_activation=True, epsilon=1e-5)

    # you can use it with arbitary number of classes
    if (weights == 'pascal_voc' and classes == 21) or (weights == 'cityscapes' and classes == 19):
        last_layer_name = 'logits_semantic'
    else:
        last_layer_name = 'custom_logits_semantic'

    x = Conv2D(classes, (1, 1), padding='same', name=last_layer_name)(x)
    size_before3 = tf.keras.backend.int_shape(img_input)
    x = Lambda(lambda xx: tf.compat.v1.image.resize(xx,
                                                    size_before3[1:3],
                                                    method='bilinear', align_corners=True))(x)

    # Ensure that the model takes into account
    # any potential predecessors of `input_tensor`.
    if input_tensor is not None:
        inputs = get_source_inputs(input_tensor)
    else:
        inputs = img_input

    if activation in {'softmax', 'sigmoid'}:
        x = tf.keras.layers.Activation(activation)(x)

    model = Model(inputs, x, name='deeplabv3plus')

    # load weights

    if weights == 'pascal_voc':
        if backbone == 'xception':
            weights_path = get_file('deeplabv3_xception_tf_dim_ordering_tf_kernels.h5',
                                    WEIGHTS_PATH_X,
                                    cache_subdir='models')
        else:
            weights_path = get_file('deeplabv3_mobilenetv2_tf_dim_ordering_tf_kernels.h5',
                                    WEIGHTS_PATH_MOBILE,
                                    cache_subdir='models')
        model.load_weights(weights_path, by_name=True)
    elif weights == 'cityscapes':
        if backbone == 'xception':
            weights_path = get_file('deeplabv3_xception_tf_dim_ordering_tf_kernels_cityscapes.h5',
                                    WEIGHTS_PATH_X_CS,
                                    cache_subdir='models')
        else:
            weights_path = get_file('deeplabv3_mobilenetv2_tf_dim_ordering_tf_kernels_cityscapes.h5',
                                    WEIGHTS_PATH_MOBILE_CS,
                                    cache_subdir='models')
        model.load_weights(weights_path, by_name=True)
    return model

def preprocess_input(x):
    """Preprocesses a numpy array encoding a batch of images.
    # Arguments
        x: a 4D numpy array consists of RGB values within [0, 255].
    # Returns
        Input array scaled to [-1.,1.]
    """
    return preprocess_input(x, mode='tf')

# %%
from tensorflow.keras import backend as K

def dice_coef(y_true, y_pred, smooth=1):
    """
    Dice = (2*|X & Y|)/ (|X|+ |Y|)
         =  2*sum(|A*B|)/(sum(A^2)+sum(B^2))
    ref: https://arxiv.org/pdf/1606.04797v1.pdf
    """
    intersection = K.sum(K.abs(y_true * y_pred), axis=-1)
    return (2. * intersection + smooth) / (K.sum(K.square(y_true),-1) + K.sum(K.square(y_pred),-1) + smooth)

def dice_coef_loss(y_true, y_pred):
    return 1-dice_coef(y_true, y_pred)

def recall_m(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    recall = true_positives / (possible_positives + K.epsilon())
    return recall

def precision_m(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    return precision

def f1_m(y_true, y_pred):
    precision = precision_m(y_true, y_pred)
    recall = recall_m(y_true, y_pred)
    return 2*((precision*recall)/(precision+recall+K.epsilon()))

  
def focal_loss(y_true, y_pred, alpha=0.25, gamma=2):
    
    def focal_loss_with_logits(logits, targets, alpha, gamma, y_pred):
        weight_a = alpha * (1 - y_pred) ** gamma * targets
        weight_b = (1 - alpha) * y_pred ** gamma * (1 - targets)

        return (tf.log1p(tf.exp(-tf.abs(logits))) + tf.nn.relu(-logits)) * (weight_a + weight_b) + logits * weight_b 

    def loss(y_true, y_pred):
        y_pred = tf.clip_by_value(y_pred, tf.keras.backend.epsilon(), 1 - tf.keras.backend.epsilon())
        logits = tf.log(y_pred / (1 - y_pred))

        loss = focal_loss_with_logits(logits=logits, targets=y_true, alpha=alpha, gamma=gamma, y_pred=y_pred)

        # or reduce_sum and/or axis=-1
        return tf.reduce_mean(loss)

    loss = loss(y_true, y_pred)
    return loss    
    

def focal_dice(y_true, y_pred):
    return dice_coef_loss(y_true, y_pred) + focal_loss(y_true, y_pred) 
    


binary_crossentropy = "binary_crossentropy"
from keras import optimizers

RMS = optimizers.RMSprop()
sgd = optimizers.SGD(lr=0.01, clipnorm=1.)

model = Deeplabv3(weights='pascal_voc', input_tensor=None, input_shape=(256, 256, 3), classes=1, backbone='mobilenetv2',
              OS=16, alpha=1., activation='sigmoid') 
model.compile(optimizer=tf.keras.optimizers.Adam(), loss = focal_dice, metrics=["accuracy", f1_m, precision_m, recall_m, dice_coef])
#model.summary()

callbacks = [
    EarlyStopping(patience=50,   verbose=1),
    ReduceLROnPlateau(factor=0.1,  patience=5, min_lr=0.00001, verbose=1),
    ModelCheckpoint('model-deeplabvplus.h5', monitor='val_loss', mode='min' , save_best_only=True, save_weights_only=True, verbose=1)
]

results=model.fit(X_train, y_train, batch_size=32, epochs=100, callbacks=callbacks , validation_split=0.3 , verbose = 1)
# Out:
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\ops\init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# Train on 1029 samples, validate on 441 samples
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\ops\math_grad.py:1205: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Epoch 1/100
# 1024/1029 [============================>.] - ETA: 0s - loss: 0.1930 - acc: 0.7171 - f1_m: 0.2571 - precision_m: 0.5443 - recall_m: 0.1891 - dice_coef: 0.8883
# Epoch 00001: val_loss improved from inf to 0.39108, saving model to model-deeplabvplus.h5
# 1029/1029 [==============================] - 85s 82ms/sample - loss: 0.1929 - acc: 0.7172 - f1_m: 0.2629 - precision_m: 0.5506 - recall_m: 0.1930 - dice_coef: 0.8884 - val_loss: 0.3911 - val_acc: 0.7488 - val_f1_m: 0.0274 - val_precision_m: 0.9314 - val_recall_m: 0.0139 - val_dice_coef: 0.8816
# Epoch 2/100
# 1024/1029 [============================>.] - ETA: 0s - loss: 0.1132 - acc: 0.8241 - f1_m: 0.6010 - precision_m: 0.8077 - recall_m: 0.4811 - dice_coef: 0.9293
# Epoch 00002: val_loss improved from 0.39108 to 0.23588, saving model to model-deeplabvplus.h5
# 1029/1029 [==============================] - 58s 56ms/sample - loss: 0.1131 - acc: 0.8243 - f1_m: 0.6036 - precision_m: 0.8086 - recall_m: 0.4842 - dice_coef: 0.9294 - val_loss: 0.2359 - val_acc: 0.8106 - val_f1_m: 0.5158 - val_precision_m: 0.7363 - val_recall_m: 0.3973 - val_dice_coef: 0.9191
# Epoch 3/100
# 1024/1029 [============================>.] - ETA: 0s - loss: 0.0950 - acc: 0.8556 - f1_m: 0.6951 - precision_m: 0.8421 - recall_m: 0.5933 - dice_coef: 0.9414
# Epoch 00003: val_loss did not improve from 0.23588
# 1029/1029 [==============================] - 57s 56ms/sample - loss: 0.0949 - acc: 0.8558 - f1_m: 0.6962 - precision_m: 0.8416 - recall_m: 0.5954 - dice_coef: 0.9414 - val_loss: 0.3246 - val_acc: 0.7974 - val_f1_m: 0.6363 - val_precision_m: 0.5862 - val_recall_m: 0.6972 - val_dice_coef: 0.9118
# Epoch 4/100
# 1024/1029 [============================>.] - ETA: 0s - loss: 0.0866 - acc: 0.8671 - f1_m: 0.7214 - precision_m: 0.8658 - recall_m: 0.6205 - dice_coef: 0.9465
# Epoch 00004: val_loss did not improve from 0.23588
# 1029/1029 [==============================] - 57s 56ms/sample - loss: 0.0866 - acc: 0.8673 - f1_m: 0.7224 - precision_m: 0.8625 - recall_m: 0.6244 - dice_coef: 0.9465 - val_loss: 0.3581 - val_acc: 0.7955 - val_f1_m: 0.6428 - val_precision_m: 0.5776 - val_recall_m: 0.7252 - val_dice_coef: 0.9103
# Epoch 5/100
# 1024/1029 [============================>.] - ETA: 0s - loss: 0.
100
# 1024/1029 [============================>.] - ETA: 0s - loss: 0.0657 - acc: 0.9011 - f1_m: 0.8021 - precision_m: 0.9028 - recall_m: 0.7224 - dice_coef: 0.9592
# Epoch 00011: val_loss improved from 0.23588 to 0.23168, saving model to model-deeplabvplus.h5
# 1029/1029 [==============================] - 58s 57ms/sample - loss: 0.0658 - acc: 0.9010 - f1_m: 0.8010 - precision_m: 0.9042 - recall_m: 0.7199 - dice_coef: 0.9592 - val_loss: 0.2317 - val_acc: 0.8258 - val_f1_m: 0.6727 - val_precision_m: 0.6444 - val_recall_m: 0.7041 - val_dice_coef: 0.9256
# Epoch 12/100
# 1024/1029 [============================>.] - ETA: 0s - loss: 0.0651 - acc: 0.9017 - f1_m: 0.8038 - precision_m: 0.9052 - recall_m: 0.7234 - dice_coef: 0.9596
# Epoch 00012: val_loss improved from 0.23168 to 0.21786, saving model to model-deeplabvplus.h5
# 1029/1029 [==============================] - 58s 57ms/sample - loss: 0.0651 - acc: 0.9019 - f1_m: 0.8051 - precision_m: 0.9044 - recall_m: 0.7263 - dice_coef: 0.9596 - val_loss: 0.2179 - val_acc: 0.8280 - val_f1_m: 0.6735 - val_precision_m: 0.6511 - val_recall_m: 0.6981 - val_dice_coef: 0.9269
# Epoch 13/100
# 1024/1029 [============================>.] - ETA: 0s - loss: 0.0647 - acc: 0.9016 - f1_m: 0.8025 - precision_m: 0.9084 - recall_m: 0.7194 - dice_coef: 0.9599
# Epoch 00013: val_loss improved from 0.21786 to 0.20199, saving model to model-deeplabvplus.h5
# 1029/1029 [==============================] - 59s 57ms/sample - loss: 0.0647 - acc: 0.9016 - f1_m: 0.8024 - precision_m: 0.9076 - recall_m: 0.7198 - dice_coef: 0.9599 - val_loss: 0.2020 - val_acc: 0.8313 - val_f1_m: 0.6752 - val_precision_m: 0.6600 - val_recall_m: 0.6920 - val_dice_coef: 0.9286
# Epoch 14/100
# 1024/1029 [============================>.] - ETA: 0s - loss: 0.0642 - acc: 0.9034 - f1_m: 0.8077 - precision_m: 0.9065 - recall_m: 0.7290 - dice_coef: 0.9602
# Epoch 00014: val_loss improved from 0.20199 to 0.18622, saving model to model-deeplabvplus.h5
# 1029/1029 [==============================] - 58s 57ms/sample - loss: 0.0641 - acc: 0.9035 - f1_m: 0.8087 - precision_m: 0.9062 - recall_m: 0.7310 - dice_coef: 0.9603 - val_loss: 0.1862 - val_acc: 0.8356 - val_f1_m: 0.6750 - val_precision_m: 0.6783 - val_recall_m: 0.6728 - val_dice_coef: 0.9310
# Epoch 15/100
# 1024/1029 [============================>.] - ETA: 0s - loss: 0.0634 - acc: 0.9037 - f1_m: 0.8073 - precision_m: 0.9107 - recall_m: 0.7258 - dice_coef: 0.9607
# Epoch 00015: val_loss improved from 0.18622 to 0.17589, saving model to model-deeplabvplus.h5
# 1029/1029 [==============================] - 58s 57ms/sample - loss: 0.0635 - acc: 0.9035 - f1_m: 0.8047 - precision_m: 0.9100 - recall_m: 0.7222 - dice_coef: 0.9607 - val_loss: 0.1759 - val_acc: 0.8371 - val_f1_m: 0.6744 - val_precision_m: 0.6852 - val_recall_m: 0.6644 - val_dice_coef: 0.9319
# Epoch 16/100
# 1024/1029 [============================>.] - ETA: 0s - loss: 0.0628 - acc: 0.9058 - f1_m: 0.8127 - precision_m: 0.9083 - recall_m: 0.7360 - dice_coef: 0.9611
# Epoch 00016: val_loss improved from 0.17589 to 0.16369, saving model to model-deeplabvplus.h5
# 1029/1029 [==============================] - 59s 57ms/sample - loss: 0.0628 - acc: 0.9057 - f1_m: 0.8120 - precision_m: 0.9087 - recall_m: 0.7345 - dice_coef: 0.9611 - val_loss: 0.1637 - val_acc: 0.8402 - val_f1_m: 0.6722 - val_precision_m: 0.7024 - val_recall_m: 0.6449 - val_dice_coef: 0.9337
# Epoch 17/100
# 1024/1029 [============================>.] - ETA: 0s - loss: 0.0621 - acc: 0.9065 - f1_m: 0.8141 - precision_m: 0.9103 - recall_m: 0.7368 - dice_coef: 0.9614
# Epoch 00017: val_loss improved from 0.16369 to 0.15327, saving model to model-deeplabvplus.h5
# 1029/1029 [==============================] - 59s 57ms/sample - loss: 0.0621 - acc: 0.9065 - f1_m: 0.8143 - precision_m: 0.9102 - recall_m: 0.7372 - dice_coef: 0.9615 - val_loss: 0.1533 - val_acc: 0.8429 - val_f1_m: 0.6625 - val_precision_m: 0.7298 - val_recall_m: 0.6073 - val_dice_coef: 0.9357
# Epoch 18/100
# 1024/1029 [============================>.] - ETA: 0s - loss: 0.0622 - acc: 0.9064 - f1_m: 0.8141 - precision_m: 0.9112 - recall_m: 0.7369 - dice_coef: 0.9615
# Epoch 00018: val_loss improved from 0.15327 to 0.14700, saving model to model-deeplabvplus.h5
# 1029/1029 [==============================] - 59s 57ms/sample - loss: 0.0622 - acc: 0.9064 - f1_m: 0.8138 - precision_m: 0.9103 - recall_m: 0.7370 - dice_coef: 0.9615 - val_loss: 0.1470 - val_acc: 0.8440 - val_f1_m: 0.6670 - val_precision_m: 0.7295 - val_recall_m: 0.6150 - val_dice_coef: 0.9360
# Epoch 19/100
# 1024/1029 [============================>.] - ETA: 0s - loss: 0.0611 - acc: 0.9073 - f1_m: 0.8150 - precision_m: 0.9155 - recall_m: 0.7350 - dice_coef: 0.9621
# Epoch 00019: val_loss improved from 0.14700 to 0.14156, saving model to model-deeplabvplus.h5
# 1029/1029 [==============================] - 58s 57ms/sample - loss: 0.0612 - acc: 0.9072 - f1_m: 0.8138 - precision_m: 0.9149 - recall_m: 0.7334 - dice_coef: 0.9620 - val_loss: 0.1416 - val_acc: 0.8444 - val_f1_m: 0.6561 - val_precision_m: 0.7474 - val_recall_m: 0.5853 - val_dice_coef: 0.9368
# Epoch 20/100
# 1024/1029 [============================>.] - ETA: 0s - loss: 0.0605 - acc: 0.9088 - f1_m: 0.8192 - precision_m: 0.9147 - recall_m: 0.7427 - dice_coef: 0.9625
# Epoch 00020: val_loss improved from 0.14156 to 0.13874, saving model to model-deeplabvplus.h5
# 1029/1029 [==============================] - 59s 57ms/sample - loss: 0.0605 - acc: 0.9089 - f1_m: 0.8202 - precision_m: 0.9133 - recall_m: 0.7454 - dice_coef: 0.9625 - val_loss: 0.1387 - val_acc: 0.8453 - val_f1_m: 0.6617 - val_precision_m: 0.7458 - val_recall_m: 0.5956 - val_dice_coef: 0.9370
# Epoch 21/100
# 1024/1029 [============================>.] - ETA: 0s - loss: 0.0599 - acc: 0.9096 - f1_m: 0.8206 - precision_m: 0.9150 - recall_m: 0.7448 - dice_coef: 0.9629
# Epoch 00021: val_loss improved from 0.13874 to 0.13679, saving model to model-deeplabvplus.h5
# 1029/1029 [==============================] - 58s 57ms/sample - loss: 0.0600 - acc: 0.9094 - f1_m: 0.8190 - precision_m: 0.9159 - recall_m: 0.7417 - dice_coef: 0.9628 - val_loss: 0.1368 - val_acc: 0.8453 - val_f1_m: 0.6529 - val_precision_m: 0.7597 - val_recall_m: 0.5728 - val_dice_coef: 0.9376
# Epoch 22/100
# 1024/1029 [============================>.] - ETA: 0s - loss: 0.0591 - acc: 0.9115 - f1_m: 0.8250 - precision_m: 0.9158 - recall_m: 0.7512 - dice_coef: 0.9634
# Epoch 00022: val_loss improved from 0.13679 to 0.13208, saving model to model-deeplabvplus.h5
# 1029/1029 [==============================] - 59s 57ms/sample - loss: 0.0592 - acc: 0.9113 - f1_m: 0.8241 - precision_m: 0.9160 - recall_m: 0.7495 - dice_coef: 0.9634 - val_loss: 0.1321 - val_acc: 0.8464 - val_f1_m: 0.6551 - val_precision_m: 0.7627 - val_recall_m: 0.5747 - val_dice_coef: 0.9381
# Epoch 23/100
# 1024/1029 [============================>.] - ETA: 0s - loss: 0.0586 - acc: 0.9125 - f1_m: 0.8271 - precision_m: 0.9159 - recall_m: 0.7547 - dice_coef: 0.9638
# Epoch 00023: val_loss improved from 0.13208 to 0.12879, saving model to model-deeplabvplus.h5
# 1029/1029 [==============================] - 59s 57ms/sample - loss: 0.0589 - acc: 0.9120 - f1_m: 0.8231 - precision_m: 0.9155 - recall_m: 0.7489 - dice_coef: 0.9636 - val_loss: 0.1288 - val_acc: 0.8464 - val_f1_m: 0.6528 - val_precision_m: 0.7668 - val_recall_m: 0.5692 - val_dice_coef: 0.9380
# Epoch 24/100
# 1024/1029 [============================>.] - ETA: 0s - loss: 0.
100
# 1024/1029 [============================>.] - ETA: 0s - loss: 0.0546 - acc: 0.9179 - f1_m: 0.8388 - precision_m: 0.9247 - recall_m: 0.7682 - dice_coef: 0.9662
# Epoch 00030: val_loss improved from 0.12134 to 0.11953, saving model to model-deeplabvplus.h5
# 1029/1029 [==============================] - 59s 57ms/sample - loss: 0.0547 - acc: 0.9179 - f1_m: 0.8384 - precision_m: 0.9240 - recall_m: 0.7679 - dice_coef: 0.9662 - val_loss: 0.1195 - val_acc: 0.8500 - val_f1_m: 0.6609 - val_precision_m: 0.7734 - val_recall_m: 0.5775 - val_dice_coef: 0.9389
# Epoch 31/100
# 1024/1029 [============================>.] - ETA: 0s - loss: 0.0542 - acc: 0.9189 - f1_m: 0.8410 - precision_m: 0.9246 - recall_m: 0.7718 - dice_coef: 0.9664
# Epoch 00031: val_loss improved from 0.11953 to 0.11923, saving model to model-deeplabvplus.h5
# 1029/1029 [==============================] - 59s 57ms/sample - loss: 0.0543 - acc: 0.9188 - f1_m: 0.8406 - precision_m: 0.9255 - recall_m: 0.7705 - dice_coef: 0.9664 - val_loss: 0.1192 - val_acc: 0.8487 - val_f1_m: 0.6494 - val_precision_m: 0.7900 - val_recall_m: 0.5517 - val_dice_coef: 0.9393
# Epoch 32/100
# 1024/1029 [============================>.] - ETA: 0s - loss: 0.0534 - acc: 0.9203 - f1_m: 0.8440 - precision_m: 0.9252 - recall_m: 0.7763 - dice_coef: 0.9669
# Epoch 00032: val_loss did not improve from 0.11923
# 1029/1029 [==============================] - 58s 57ms/sample - loss: 0.0534 - acc: 0.9203 - f1_m: 0.8446 - precision_m: 0.9248 - recall_m: 0.7775 - dice_coef: 0.9669 - val_loss: 0.1204 - val_acc: 0.8451 - val_f1_m: 0.6243 - val_precision_m: 0.8140 - val_recall_m: 0.5067 - val_dice_coef: 0.9393
# Epoch 33/100
# 1024/1029 [============================>.] - ETA: 0s - loss: 0.0530 - acc: 0.9204 - f1_m: 0.8440 - precision_m: 0.9278 - recall_m: 0.7747 - dice_coef: 0.9673
# Epoch 00033: val_loss did not improve from 0.11923
# 1029/1029 [==============================] - 58s 57ms/sample - loss: 0.0530 - acc: 0.9203 - f1_m: 0.8439 - precision_m: 0.9278 - recall_m: 0.7746 - dice_coef: 0.9673 - val_loss: 0.1192 - val_acc: 0.8500 - val_f1_m: 0.6564 - val_precision_m: 0.7854 - val_recall_m: 0.5644 - val_dice_coef: 0.9396
# Epoch 34/100
# 1024/1029 [============================>.] - ETA: 0s - loss: 0.0521 - acc: 0.9222 - f1_m: 0.8480 - precision_m: 0.9281 - recall_m: 0.7808 - dice_coef: 0.9677
# Epoch 00034: val_loss improved from 0.11923 to 0.11829, saving model to model-deeplabvplus.h5
# 1029/1029 [==============================] - 58s 57ms/sample - loss: 0.0521 - acc: 0.9221 - f1_m: 0.8476 - precision_m: 0.9291 - recall_m: 0.7795 - dice_coef: 0.9677 - val_loss: 0.1183 - val_acc: 0.8505 - val_f1_m: 0.6584 - val_precision_m: 0.7855 - val_recall_m: 0.5672 - val_dice_coef: 0.9398
# Epoch 35/100
# 1024/1029 [============================>.] - ETA: 0s - loss: 0.0519 - acc: 0.9224 - f1_m: 0.8484 - precision_m: 0.9283 - recall_m: 0.7819 - dice_coef: 0.9680
# Epoch 00035: val_loss improved from 0.11829 to 0.11802, saving model to model-deeplabvplus.h5
# 1029/1029 [==============================] - 59s 57ms/sample - loss: 0.0521 - acc: 0.9221 - f1_m: 0.8465 - precision_m: 0.9285 - recall_m: 0.7787 - dice_coef: 0.9679 - val_loss: 0.1180 - val_acc: 0.8506 - val_f1_m: 0.6585 - val_precision_m: 0.7838 - val_recall_m: 0.5681 - val_dice_coef: 0.9399
# Epoch 36/100
# 1024/1029 [============================>.] - ETA: 0s - loss: 0.0518 - acc: 0.9231 - f1_m: 0.8503 - precision_m: 0.9272 - recall_m: 0.7858 - dice_coef: 0.9680
# Epoch 00036: val_loss improved from 0.11802 to 0.11580, saving model to model-deeplabvplus.h5
# 1029/1029 [==============================] - 59s 57ms/sample - loss: 0.
val_loss did not improve from 0.11504
# 1029/1029 [==============================] - 58s 57ms/sample - loss: 0.0468 - acc: 0.9302 - f1_m: 0.8627 - precision_m: 0.9367 - recall_m: 0.8002 - dice_coef: 0.9709 - val_loss: 0.1176 - val_acc: 0.8556 - val_f1_m: 0.6764 - val_precision_m: 0.7845 - val_recall_m: 0.5947 - val_dice_coef: 0.9420
# Epoch 51/100
# 1024/1029 [============================>.] - ETA: 0s - loss: 0.0473 - acc: 0.9295 - f1_m: 0.8634 - precision_m: 0.9366 - recall_m: 0.8014 - dice_coef: 0.9707
# Epoch 00051: val_loss did not improve from 0.11504
# 1029/1029 [==============================] - 58s 57ms/sample - loss: 0.0473 - acc: 0.9294 - f1_m: 0.8631 - precision_m: 0.9371 - recall_m: 0.8006 - dice_coef: 0.9707 - val_loss: 0.1177 - val_acc: 0.8561 - val_f1_m: 0.6797 - val_precision_m: 0.7832 - val_recall_m: 0.6007 - val_dice_coef: 0.9421
# Epoch 52/100
# 1024/1029 [============================>.] - ETA: 0s - loss: 0.0465 - acc: 0.9312 - f1_m: 0.8673 - precision_m: 0.9366 - recall_m: 0.8079 - dice_coef: 0.9711
# Epoch 00052: val_loss did not improve from 0.11504
# 1029/1029 [==============================] - 58s 57ms/sample - loss: 0.0466 - acc: 0.9310 - f1_m: 0.8656 - precision_m: 0.9350 - recall_m: 0.8061 - dice_coef: 0.9711 - val_loss: 0.1181 - val_acc: 0.8564 - val_f1_m: 0.6820 - val_precision_m: 0.7802 - val_recall_m: 0.6060 - val_dice_coef: 0.9421
# Epoch 53/100
# 1024/1029 [============================>.] - ETA: 0s - loss: 0.0464 - acc: 0.9308 - f1_m: 0.8660 - precision_m: 0.9380 - recall_m: 0.8045 - dice_coef: 0.9712
# Epoch 00053: val_loss did not improve from 0.11504
# 1029/1029 [==============================] - 58s 57ms/sample - loss: 0.0467 - acc: 0.9305 - f1_m: 0.8635 - precision_m: 0.9389 - recall_m: 0.8001 - dice_coef: 0.9711 - val_loss: 0.1182 - val_acc: 0.8562 - val_f1_m: 0.6796 - val_precision_m: 0.7831 - val_recall_m: 0.6006 - val_dice_coef: 0.9422
# Epoch 54/100
# 1024/1029 [============================>.] - ETA: 0s - loss: 0.0463 - acc: 0.9313 - f1_m: 0.8675 - precision_m: 0.9371 - recall_m: 0.8078 - dice_coef: 0.9712
# Epoch 00054: val_loss did not improve from 0.11504
# 1029/1029 [==============================] - 58s 57ms/sample - loss: 0.0463 - acc: 0.9314 - f1_m: 0.8674 - precision_m: 0.9363 - recall_m: 0.8081 - dice_coef: 0.9712 - val_loss: 0.1181 - val_acc: 0.8564 - val_f1_m: 0.6799 - val_precision_m: 0.7833 - val_recall_m: 0.6010 - val_dice_coef: 0.9424
# Epoch 55/100
# 1024/1029 [============================>.] - ETA: 0s - loss: 0.0462 - acc: 0.9311 - f1_m: 0.8668 - precision_m: 0.9388 - recall_m: 0.8053 - dice_coef: 0.9713
# Epoch 00055: val_loss did not improve from 0.11504
# 1029/1029 [==============================] - 58s 57ms/sample - loss: 0.0462 - acc: 0.9311 - f1_m: 0.8659 - precision_m: 0.9382 - recall_m: 0.8043 - dice_coef: 0.9713 - val_loss: 0.1183 - val_acc: 0.8566 - val_f1_m: 0.6819 - val_precision_m: 0.7820 - val_recall_m: 0.6054 - val_dice_coef: 0.9424
# Epoch 56/100
# 1024/1029 [============================>.] - ETA: 0s - loss: 0.0464 - acc: 0.9308 - f1_m: 0.8661 - precision_m: 0.9387 - recall_m: 0.8045 - dice_coef: 0.9712
# Epoch 00056: val_loss did not improve from 0.11504
# 1029/1029 [==============================] - 58s 57ms/sample - loss: 0.0464 - acc: 0.9308 - f1_m: 0.8663 - precision_m: 0.9383 - recall_m: 0.8050 - dice_coef: 0.9712 - val_loss: 0.1180 - val_acc: 0.8566 - val_f1_m: 0.6803 - val_precision_m: 0.7852 - val_recall_m: 0.6007 - val_dice_coef: 0.9425
# Epoch 57/100
# 1024/1029 [============================>.] - ETA: 0s - loss: 0.
100
# 1024/1029 [============================>.] - ETA: 0s - loss: 0.0458 - acc: 0.9318 - f1_m: 0.8683 - precision_m: 0.9387 - recall_m: 0.8081 - dice_coef: 0.9716
# Epoch 00064: val_loss did not improve from 0.11504
# 1029/1029 [==============================] - 58s 57ms/sample - loss: 0.0459 - acc: 0.9317 - f1_m: 0.8676 - precision_m: 0.9369 - recall_m: 0.8082 - dice_coef: 0.9716 - val_loss: 0.1209 - val_acc: 0.8586 - val_f1_m: 0.6971 - val_precision_m: 0.7654 - val_recall_m: 0.6407 - val_dice_coef: 0.9423
# Epoch 65/100
# 1024/1029 [============================>.] - ETA: 0s - loss: 0.0458 - acc: 0.9317 - f1_m: 0.8678 - precision_m: 0.9394 - recall_m: 0.8067 - dice_coef: 0.9716
# Epoch 00065: val_loss did not improve from 0.11504
# 1029/1029 [==============================] - 58s 57ms/sample - loss: 0.0458 - acc: 0.9316 - f1_m: 0.8670 - precision_m: 0.9396 - recall_m: 0.8051 - dice_coef: 0.9716 - val_loss: 0.1215 - val_acc: 0.8583 - val_f1_m: 0.6966 - val_precision_m: 0.7642 - val_recall_m: 0.6407 - val_dice_coef: 0.9422
# Epoch 66/100
# 1024/1029 [============================>.] - ETA: 0s - loss: 0.0460 - acc: 0.9319 - f1_m: 0.8685 - precision_m: 0.9370 - recall_m: 0.8099 - dice_coef: 0.9716
# Epoch 00066: val_loss did not improve from 0.11504
# 1029/1029 [==============================] - 58s 57ms/sample - loss: 0.0460 - acc: 0.9318 - f1_m: 0.8683 - precision_m: 0.9371 - recall_m: 0.8094 - dice_coef: 0.9716 - val_loss: 0.1211 - val_acc: 0.8586 - val_f1_m: 0.6967 - val_precision_m: 0.7664 - val_recall_m: 0.6390 - val_dice_coef: 0.9424
# Epoch 67/100
# 1024/1029 [============================>.] - ETA: 0s - loss: 0.0458 - acc: 0.9316 - f1_m: 0.8678 - precision_m: 0.9401 - recall_m: 0.8063 - dice_coef: 0.9717
# Epoch 00067: val_loss did not improve from 0.11504
# 1029/1029 [==============================] - 58s 57ms/sample - loss: 0.0458 - acc: 0.9316 - f1_m: 0.8674 - precision_m: 0.9406 - recall_m: 0.8052 - dice_coef: 0.9716 - val_loss: 0.1219 - val_acc: 0.8588 - val_f1_m: 0.6999 - val_precision_m: 0.7613 - val_recall_m: 0.6481 - val_dice_coef: 0.9423
# Epoch 68/100
# 1024/1029 [============================>.] - ETA: 0s - loss: 0.0458 - acc: 0.9320 - f1_m: 0.8689 - precision_m: 0.9377 - recall_m: 0.8097 - dice_coef: 0.9716
# Epoch 00068: val_loss did not improve from 0.11504
# 1029/1029 [==============================] - 58s 57ms/sample - loss: 0.0459 - acc: 0.9320 - f1_m: 0.8684 - precision_m: 0.9368 - recall_m: 0.8096 - dice_coef: 0.9716 - val_loss: 0.1216 - val_acc: 0.8587 - val_f1_m: 0.6983 - val_precision_m: 0.7633 - val_recall_m: 0.6440 - val_dice_coef: 0.9424
# Epoch 69/100
# 1024/1029 [============================>.] - ETA: 0s - loss: 0.0458 - acc: 0.9321 - f1_m: 0.8691 - precision_m: 0.9375 - recall_m: 0.8105 - dice_coef: 0.9717
# Epoch 00069: val_loss did not improve from 0.11504
# 1029/1029 [==============================] - 58s 57ms/sample - loss: 0.0460 - acc: 0.9319 - f1_m: 0.8670 - precision_m: 0.9377 - recall_m: 0.8069 - dice_coef: 0.9716 - val_loss: 0.1209 - val_acc: 0.8588 - val_f1_m: 0.6961 - val_precision_m: 0.7677 - val_recall_m: 0.6370 - val_dice_coef: 0.9427
# Epoch 70/100
# 1024/1029 [============================>.] - ETA: 0s - loss: 0.0459 - acc: 0.9319 - f1_m: 0.8684 - precision_m: 0.9379 - recall_m: 0.8090 - dice_coef: 0.9717
# Epoch 00070: val_loss did not improve from 0.11504
# 1029/1029 [==============================] - 58s 57ms/sample - loss: 0.0460 - acc: 0.9317 - f1_m: 0.8669 - precision_m: 0.9381 - recall_m: 0.8063 - dice_coef: 0.9716 - val_loss: 0.1208 - val_acc: 0.8586 - val_f1_m: 0.6953 - val_precision_m: 0.7681 - val_recall_m: 0.6356 - val_dice_coef: 0.9426
# Epoch 71/100
# 1024/1029 [============================>.] - ETA: 0s - loss: 0.0454 - acc: 0.9325 - f1_m: 0.8696 - precision_m: 0.9395 - recall_m: 0.8097 - dice_coef: 0.9719
# Epoch 00071: val_loss did not improve from 0.11504
# 1029/1029 [==============================] - 58s 57ms/sample - loss: 0.0455 - acc: 0.9323 - f1_m: 0.8677 - precision_m: 0.9389 - recall_m: 0.8070 - dice_coef: 0.9718 - val_loss: 0.1214 - val_acc: 0.8588 - val_f1_m: 0.6974 - val_precision_m: 0.7660 - val_recall_m: 0.6405 - val_dice_coef: 0.9427
# Epoch 72/100
# 1024/1029 [============================>.] - ETA: 0s - loss: 0.0456 - acc: 0.9322 - f1_m: 0.8692 - precision_m: 0.9391 - recall_m: 0.8094 - dice_coef: 0.9718
# Epoch 00072: val_loss did not improve from 0.11504
# 1029/1029 [==============================] - 58s 57ms/sample - loss: 0.0456 - acc: 0.9322 - f1_m: 0.8691 - precision_m: 0.9381 - recall_m: 0.8100 - dice_coef: 0.9718 - val_loss: 0.1232 - val_acc: 0.8589 - val_f1_m: 0.7025 - val_precision_m: 0.7563 - val_recall_m: 0.6566 - val_dice_coef: 0.9422
# Epoch 73/100
# 1024/1029 [============================>.] - ETA: 0s - loss: 0.0451 - acc: 0.9328 - f1_m: 0.8702 - precision_m: 0.9400 - recall_m: 0.8105 - dice_coef: 0.9720
# Epoch 00073: val_loss did not improve from 0.11504
# 1029/1029 [==============================] - 58s 57ms/sample - loss: 0.0452 - acc: 0.9328 - f1_m: 0.8701 - precision_m: 0.9400 - recall_m: 0.8103 - dice_coef: 0.9720 - val_loss: 0.1225 - val_acc: 0.8590 - val_f1_m: 0.7001 - val_precision_m: 0.7606 - val_recall_m: 0.6493 - val_dice_coef: 0.9425
# Epoch 74/100
# 1024/1029 [============================>.] - ETA: 0s - loss: 0.0451 - acc: 0.9328 - f1_m: 0.8703 - precision_m: 0.9398 - recall_m: 0.8107 - dice_coef: 0.9720
# Epoch 00074: val_loss did not improve from 0.11504
# 1029/1029 [==============================] - 58s 57ms/sample - loss: 0.0452 - acc: 0.9328 - f1_m: 0.8697 - precision_m: 0.9395 - recall_m: 0.8100 - dice_coef: 0.9720 - val_loss: 0.1226 - val_acc: 0.8586 - val_f1_m: 0.6989 - val_precision_m: 0.7614 - val_recall_m: 0.6464 - val_dice_coef: 0.9424
# Epoch 75/100
# 1024/1029 [============================>.] - ETA: 0s - loss: 0.0452 - acc: 0.9326 - f1_m: 0.8699 - precision_m: 0.9404 - recall_m: 0.8094 - dice_coef: 0.9720
# Epoch 00075: val_loss did not improve from 0.11504
# 1029/1029 [==============================] - 58s 57ms/sample - loss: 0.0452 - acc: 0.9326 - f1_m: 0.8696 - precision_m: 0.9394 - recall_m: 0.8098 - dice_coef: 0.9720 - val_loss: 0.1226 - val_acc: 0.8586 - val_f1_m: 0.6989 - val_precision_m: 0.7624 - val_recall_m: 0.6456 - val_dice_coef: 0.9425
# Epoch 76/100
# 1024/1029 [============================>.] - ETA: 0s - loss: 0.0450 - acc: 0.9329 - f1_m: 0.8704 - precision_m: 0.9407 - recall_m: 0.8103 - dice_coef: 0.9721
# Epoch 00076: val_loss did not improve from 0.11504
# 1029/1029 [==============================] - 58s 57ms/sample - loss: 0.0450 - acc: 0.9329 - f1_m: 0.8705 - precision_m: 0.9401 - recall_m: 0.8109 - dice_coef: 0.9721 - val_loss: 0.1220 - val_acc: 0.8583 - val_f1_m: 0.6948 - val_precision_m: 0.7681 - val_recall_m: 0.6346 - val_dice_coef: 0.9427
# Epoch 77/100
# 1024/1029 [============================>.] - ETA: 0s - loss: 0.0455 - acc: 0.9326 - f1_m: 0.8702 - precision_m: 0.9382 - recall_m: 0.8119 - dice_coef: 0.9719
# Epoch 00077: val_loss did not improve from 0.11504
# 1029/1029 [==============================] - 58s 57ms/sample - loss: 0.0455 - acc: 0.9325 - f1_m: 0.8700 - precision_m: 0.9385 - recall_m: 0.8113 - dice_coef: 0.9719 - val_loss: 0.1220 - val_acc: 0.8584 - val_f1_m: 0.6948 - val_precision_m: 0.7678 - val_recall_m: 0.6352 - val_dice_coef: 0.9428
# Epoch 78/100
# 1024/1029 [============================>.] - ETA: 0s - loss: 0.0450 - acc: 0.9329 - f1_m: 0.8704 - precision_m: 0.9403 - recall_m: 0.8103 - dice_coef: 0.9721
# Epoch 00078: val_loss did not improve from 0.11504
# 1029/1029 [==============================] - 58s 57ms/sample - loss: 0.0451 - acc: 0.9328 - f1_m: 0.8699 - precision_m: 0.9402 - recall_m: 0.8097 - dice_coef: 0.9721 - val_loss: 0.1235 - val_acc: 0.8587 - val_f1_m: 0.6988 - val_precision_m: 0.7615 - val_recall_m: 0.6462 - val_dice_coef: 0.9426
# Epoch 79/100
# 1024/1029 [============================>.] - ETA: 0s - loss: 0.0449 - acc: 0.9335 - f1_m: 0.8719 - precision_m: 0.9392 - recall_m: 0.8139 - dice_coef: 0.9722
# Epoch 00079: val_loss did not improve from 0.11504
# 1029/1029 [==============================] - 58s 57ms/sample - loss: 0.0449 - acc: 0.9334 - f1_m: 0.8710 - precision_m: 0.9373 - recall_m: 0.8138 - dice_coef: 0.9722 - val_loss: 0.1234 - val_acc: 0.8587 - val_f1_m: 0.6987 - val_precision_m: 0.7628 - val_recall_m: 0.6449 - val_dice_coef: 0.9427
# Epoch 80/100
# 1024/1029 [============================>.] - ETA: 0s - loss: 0.0450 - acc: 0.9326 - f1_m: 0.8697 - precision_m: 0.9414 - recall_m: 0.8084 - dice_coef: 0.9721
# Epoch 00080: val_loss did not improve from 0.11504
# 1029/1029 [==============================] - 58s 57ms/sample - loss: 0.0451 - acc: 0.9325 - f1_m: 0.8691 - precision_m: 0.9415 - recall_m: 0.8074 - dice_coef: 0.9721 - val_loss: 0.1241 - val_acc: 0.8589 - val_f1_m: 0.7007 - val_precision_m: 0.7588 - val_recall_m: 0.6511 - val_dice_coef: 0.9425
# Epoch 81/100
# 1024/1029 [============================>.] - ETA: 0s - loss: 0.0449 - acc: 0.9332 - f1_m: 0.8713 - precision_m: 0.9401 - recall_m: 0.8123 - dice_coef: 0.9722
# Epoch 00081: val_loss did not improve from 0.11504
# 1029/1029 [==============================] - 58s 57ms/sample - loss: 0.0449 - acc: 0.9332 - f1_m: 0.8716 - precision_m: 0.9395 - recall_m: 0.8133 - dice_coef: 0.9722 - val_loss: 0.1223 - val_acc: 0.8579 - val_f1_m: 0.6918 - val_precision_m: 0.7705 - val_recall_m: 0.6284 - val_dice_coef: 0.9429
# Epoch 82/100
# 1024/1029 [============================>.] - ETA: 0s - loss: 0.0448 - acc: 0.9333 - f1_m: 0.8713 - precision_m: 0.9403 - recall_m: 0.8120 - dice_coef: 0.9722
# Epoch 00082: val_loss did not improve from 0.11504
# 1029/1029 [==============================] - 58s 57ms/sample - loss: 0.0449 - acc: 0.9333 - f1_m: 0.8711 - precision_m: 0.9401 - recall_m: 0.8117 - dice_coef: 0.9722 - val_loss: 0.1238 - val_acc: 0.8586 - val_f1_m: 0.6982 - val_precision_m: 0.7627 - val_recall_m: 0.6440 - val_dice_coef: 0.9427
# Epoch 83/100
# 1024/1029 [============================>.] - ETA: 0s - loss: 0.0447 - acc: 0.9334 - f1_m: 0.8719 - precision_m: 0.9403 - recall_m: 0.8131 - dice_coef: 0.9723
# Epoch 00083: val_loss did not improve from 0.11504
# 1029/1029 [==============================] - 58s 57ms/sample - loss: 0.0447 - acc: 0.9335 - f1_m: 0.8715 - precision_m: 0.9393 - recall_m: 0.8133 - dice_coef: 0.9723 - val_loss: 0.1235 - val_acc: 0.8586 - val_f1_m: 0.6983 - val_precision_m: 0.7627 - val_recall_m: 0.6445 - val_dice_coef: 0.9427
# Epoch 84/100
# 1024/1029 [============================>.] - ETA: 0s - loss: 0.0449 - acc: 0.9332 - f1_m: 0.8715 - precision_m: 0.9404 - recall_m: 0.8125 - dice_coef: 0.9723
# Epoch 00084: val_loss did not improve from 0.11504
# 1029/1029 [==============================] - 58s 57ms/sample - loss: 0.0450 - acc: 0.9332 - f1_m: 0.8700 - precision_m: 0.9364 - recall_m: 0.8131 - dice_coef: 0.9722 - val_loss: 0.1233 - val_acc: 0.8585 - val_f1_m: 0.6970 - val_precision_m: 0.7647 - val_recall_m: 0.6408 - val_dice_coef: 0.9428
# Epoch 85/100
# 1024/1029 [============================>.] - ETA: 0s - loss: 0.0449 - acc: 0.9327 - f1_m: 0.8698 - precision_m: 0.9421 - recall_m: 0.8083 - dice_coef: 0.9723
# Epoch 00085: val_loss did not improve from 0.11504
# 1029/1029 [==============================] - 58s 57ms/sample - loss: 0.0450 - acc: 0.9326 - f1_m: 0.8689 - precision_m: 0.9410 - recall_m: 0.8074 - dice_coef: 0.9722 - val_loss: 0.1249 - val_acc: 0.8589 - val_f1_m: 0.7022 - val_precision_m: 0.7571 - val_recall_m: 0.6552 - val_dice_coef: 0.9425
# Epoch 86/100
# 1024/1029 [============================>.] - ETA: 0s - loss: 0.0448 - acc: 0.9330 - f1_m: 0.8705 - precision_m: 0.9412 - recall_m: 0.8101 - dice_coef: 0.9723
# Epoch 00086: val_loss did not improve from 0.11504
# 1029/1029 [==============================] - 58s 57ms/sample - loss: 0.0448 - acc: 0.9330 - f1_m: 0.8700 - precision_m: 0.9406 - recall_m: 0.8097 - dice_coef: 0.9723 - val_loss: 0.1254 - val_acc: 0.8588 - val_f1_m: 0.7031 - val_precision_m: 0.7562 - val_recall_m: 0.6573 - val_dice_coef: 0.9424
# Epoch 87/100
# 1024/1029 [============================>.] - ETA: 0s - loss: 0.0445 - acc: 0.9340 - f1_m: 0.8730 - precision_m: 0.9402 - recall_m: 0.8151 - dice_coef: 0.9724
# Epoch 00087: val_loss did not improve from 0.11504
# 1029/1029 [==============================] - 58s 57ms/sample - loss: 0.0446 - acc: 0.9340 - f1_m: 0.8723 - precision_m: 0.9379 - recall_m: 0.8157 - dice_coef: 0.9724 - val_loss: 0.1251 - val_acc: 0.8587 - val_f1_m: 0.6996 - val_precision_m: 0.7587 - val_recall_m: 0.6493 - val_dice_coef: 0.9426
# Epoch 88/100
# 1024/1029 [============================>.] - ETA: 0s - loss: 0.0447 - acc: 0.9332 - f1_m: 0.8710 - precision_m: 0.9418 - recall_m: 0.8106 - dice_coef: 0.9723
# Epoch 00088: val_loss did not improve from 0.11504
# 1029/1029 [==============================] - 58s 57ms/sample - loss: 0.0447 - acc: 0.9332 - f1_m: 0.8707 - precision_m: 0.9401 - recall_m: 0.8113 - dice_coef: 0.9723 - val_loss: 0.1249 - val_acc: 0.8583 - val_f1_m: 0.6981 - val_precision_m: 0.7613 - val_recall_m: 0.6448 - val_dice_coef: 0.9426
# Epoch 00088: early stopping

# %%
plt.figure(figsize=(8, 8))
plt.title("Learning curve")
plt.plot(results.history["loss"], label="loss")
plt.plot(results.history["val_loss"], label="val_loss")
plt.plot( np.argmin(results.history["val_loss"]), np.min(results.history["val_loss"]), marker="x", color="r", label="best model")
plt.xlabel("Epochs")
plt.ylabel("log_loss")
plt.legend();
plt.savefig("loss.png")

# %%
plt.figure(figsize=(8, 8))
plt.title("Learning curve")
plt.plot(results.history["f1_m"], label="f1_score")
plt.plot(results.history["val_f1_m"], label="val_f1_score")
plt.plot( np.argmin(results.history["val_f1_m"]), np.min(results.history["val_f1_m"]), marker="x", color="r", label="best model")
plt.xlabel("Epochs")
plt.ylabel("f1_score")
plt.legend();
plt.savefig("f1.png")

# %%
plt.figure(figsize=(8, 8))
plt.title("Learning curve")
plt.plot(results.history["acc"], label="accuracy")
plt.plot(results.history["val_acc"], label="val_accuracy")
plt.plot( np.argmin(results.history["val_acc"]), np.min(results.history["val_acc"]), marker="x", color="r", label="best model")
plt.xlabel("Epochs")
plt.ylabel("accuracy")
plt.legend();
plt.savefig("accuracy.png")

# %%
plt.figure(figsize=(8, 8))
plt.title("Learning curve")
plt.plot(results.history["dice_coef"], label="dice_coef")
plt.plot(results.history["val_dice_coef"], label="val_dice_coef")
plt.plot( np.argmin(results.history["val_dice_coef"]), np.min(results.history["val_dice_coef"]), marker="x", color="r", label="best model")
plt.xlabel("Epochs")
plt.ylabel("dice_coef")
plt.legend();
plt.savefig("dice_coef.png")

# %%
model.load_weights('model-deeplabvplus.h5')
loss, accuracy, f1_score, precision, recall , dice_score = model.evaluate(X_test, y_test, verbose=1)

print("loss:", loss)
print("Accuracy:", accuracy)
print("f1_score:", f1_score)
#print("unet_precision:", precision)
#print("unet_recall:", recall)
print("dice_score:", dice_score)
# Out:
# 686/686 [==============================] - 10s 15ms/sample - loss: 0.0828 - acc: 0.8932 - f1_m: 0.6808 - precision_m: 0.8444 - recall_m: 0.5841 - dice_coef: 0.9570
# loss: 0.08275405131823467
# Accuracy: 0.89317656
# f1_score: 0.68081737
# dice_score: 0.95698255
